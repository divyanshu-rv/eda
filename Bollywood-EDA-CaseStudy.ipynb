# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1em;color:#0ab6fa">Bollywood Problem Statement:-

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bwd=pd.read_excel("bollywood.xlsx")

# %%
bwd
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
bwd.describe()
# Out:
#              SlNo      Budget  BoxOfficeCollection  YoutubeViews  \
# count  149.000000  149.000000           149.000000  1.490000e+02
# mean    75.000000   29.442953            55.667248  3.337920e+06
# std     43.156691   28.237981            94.494531  3.504407e+06
# min      1.000000    2.000000             0.010000  4.354000e+03
# 25%     38.000000   11.000000             8.780000  1.076591e+06
# 50%     75.000000   21.000000            28.000000  2.375050e+06
# 75%    112.000000   35.000000            57.450000  4.550051e+06
# max    149.000000  150.000000           735.000000  2.317107e+07
#
#         YoutubeLikes  YoutubeDislikes
# count     149.000000       149.000000
# mean     7877.536913      1207.818792
# std     12748.047191      1852.692938
# min         1.000000         1.000000
# 25%      1377.000000       189.000000
# 50%      4111.000000       614.000000
# 75%      9100.000000      1419.000000
# max    101275.000000     11888.000000

# %%
bwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 11.8+ KB

# %% [markdown]
# **The data file contains box office collection and social media promotion information about movies released between 2013-2015 period. We have to study the data and make meaningful inferences and plots.**

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">Attribute Information:

# %% [markdown]
# | Column Name|Description|
# |------------|-----------|
# | SlNo.| Release Date|
# | MovieName|  Name of the Movie
# | ReleaseTime | Mentions special time of release. LW (Long Weekend), FS(Festive Season), HS(HolidaySeason),N(Normal).|
# | Genre|Genre of the film, Romance, Thriller, Action, Comedy,Etc. |
# | Budget|Movie Creation Budget|
# | BoxOfficeCollection| Box Office Collection|
# |Youtube Views|Number of Views of the Youtube trailers |
# |Youtube Likes|Number of Likes of the Youtube trailers |
# |Youtube Dislikes|Number of Dislikes of the Youtube trailers |

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">1.Let's start with understanding the data set
#
#     - How many records are present in the dataset?
#     - Check the info. Make inferences about the data types
#     - Calculate the five point summary. Write your observation
#     - Are there any missing values?
#     - Add the new columns - Year,Quarter,Month,Week,Weekday,Day,Dayofyear and Date for the Release Date
#     - What all variables are skewed or outliers are present?

# %%
# !49 records
bwd.shape
# Out:
# (149, 10)

# %%
bwd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   SlNo                 149 non-null    int64
#  1   Release Date         149 non-null    datetime64[ns]
#  2   MovieName            149 non-null    object
#  3   ReleaseTime          149 non-null    object
#  4   Genre                149 non-null    object
#  5   Budget               149 non-null    int64
#  6   BoxOfficeCollection  149 non-null    float64
#  7   YoutubeViews         149 non-null    int64
#  8   YoutubeLikes         149 non-null    int64
#  9   YoutubeDislikes      149 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(3)
# memory usage: 11.8+ KB

# %%
bwd["Release_date"]=pd.to_datetime(bwd["Release Date"])

# %%
bwd["Year"]=bwd["Release_date"].dt.year

# %%
bwd["Month Name"]=bwd["Release_date"].dt.month_name()

# %%
bwd["dayofWeek"]=bwd["Release_date"].dt.dayofweek

# %%
bwd["Quarter"]=bwd["Release_date"].dt.quarter

# %%
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1   2014-04-18                     2 States          LW    Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N     Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N     Comedy
# 145   146   2015-03-13                         NH10           N   Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148   2015-03-20                     Hunterrr           N     Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS     Action
#
# ...

# %%
bwd.skew()
# Out:
# C:\Users\DIVYAN~1\AppData\Local\Temp/ipykernel_11640/1329483636.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   bwd.skew()
# SlNo                   0.000000
# Budget                 2.059560
# BoxOfficeCollection    3.980880
# YoutubeViews           2.667002
# YoutubeLikes           4.391138
# YoutubeDislikes        3.534963
# Year                   0.479715
# dayofWeek             -6.183565
# Quarter                0.415351
# dtype: float64

# %%
plt.rcParams["figure.figsize"]=[15,10]
#plt.figure(figsize=(15,8))
bwd.hist()
plt.show()

# %%
# today.dt.dayofweek

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">2.Exploratory Data Analysis
#
#
#     A. How many movies got released in each genre? Which genre had the highest number of release?
#     B. Which Month for the different years were the maximum number of movie releases are seen?
#     C. Can we find out correlation in some of the variables?
#     D. Which genre of movies typically sees more You Tube Likes?

# %%
bwd['Genre'].unique()
# Out:
# array(['Romance', 'Thriller ', 'Comedy', ' Drama ', 'Action ', 'Action',
#        'Thriller'], dtype=object)

# %%
bwd['Genre'].value_counts()
# Out:
# Comedy      36
#  Drama      35
# Thriller    29
# Romance     25
# Action      24
# Name: Genre, dtype: int64

# %%
bwd['Genre']=bwd['Genre'].str.replace('Thriller ','Thriller')

# %%
bwd['Genre']=bwd['Genre'].str.replace('Action ','Action')

# %%
bwd['Genre']=bwd['Genre'].str.replace('Action ','Action')

# %%
bwd['Genre']=bwd['Genre'].str.replace(' Drama ','Drama')

# %%
bwd['Genre'].value_counts()
# Out:
# Comedy      36
# Drama       35
# Thriller    29
# Romance     25
# Action      24
# Name: Genre, dtype: int64

# %%
bwd['Genre'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
bwd.groupby(bwd["Year"])["Month Name"].value_counts()
# Out:
# Year  Month Name
# 2013  July           9
#       January        8
#       March          8
#       February       6
#       May            6
#       October        6
#       April          5
#       June           5
#       November       5
#       September      5
#       August         4
# 2014  May           12
#       March          8
#       January        7
#       July           7
#       April          6
#       February       6
#       June           5
#       November       5
#       September      5
#       August         4
#       October        3
#       December       2
# 2015  January        5
#       February       4
#       March          3
# Name: Month Name, dtype: int64

# %%
#bwd.groupby(bwd["Year"])["Month Name"].value_counts()

# %%
bwd.corr()
# Out:
#                          SlNo    Budget  BoxOfficeCollection  YoutubeViews  \
# SlNo                 1.000000  0.116899             0.036908      0.025027
# Budget               0.116899  1.000000             0.650401      0.589038
# BoxOfficeCollection  0.036908  0.650401             1.000000      0.588632
# YoutubeViews         0.025027  0.589038             0.588632      1.000000
# YoutubeLikes         0.018163  0.608916             0.682517      0.884055
# YoutubeDislikes      0.035949  0.665343             0.623941      0.846739
# Year                 0.132755  0.062069             0.011673      0.280666
# dayofWeek           -0.092707 -0.292194            -0.069057     -0.188258
# Quarter              0.216760  0.261116             0.270746      0.288505
#
#                      YoutubeLikes  YoutubeDislikes      Year  dayofWeek  \
# SlNo                     0.018163         0.035949  0.132755  -0.092707
# Budget                   0.608916         0.665343  0.062069  -0.292194
# ...

# %%
sns.heatmap(bwd.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
bwd.groupby(bwd["Genre"])["YoutubeLikes"].max()
# Out:
# Genre
# Action      101275
# Comedy       20472
# Drama        43767
# Romance      26622
# Thriller     18907
# Name: YoutubeLikes, dtype: int64

# %%
#D. Which genre of movies typically sees more You Tube Likes?

# %%
bwd.groupby(bwd["Genre"])["YoutubeLikes"].sum()
# Out:
# Genre
# Action      401873
# Comedy      172250
# Drama       279077
# Romance     177241
# Thriller    143312
# Name: YoutubeLikes, dtype: int64

# %%
bwd.groupby(bwd["Genre"])["YoutubeLikes"].mean()
# Out:
# Genre
# Action      16744.708333
# Comedy       4784.722222
# Drama        7973.628571
# Romance      7089.640000
# Thriller     4941.793103
# Name: YoutubeLikes, dtype: float64

# %% [markdown]
# <span style="font-family: Arial; font-weight:bold;font-size:1.5em;color:#0ab6fa">3.In-depth Analysis
#
#
#     A. Which month of the year typically sees most releases of high budgeted movies, assuming high budget is considered of 25 crore or more?
#     B. Which genre of movies typically sees more Youtube likes? Draw Boxplots for each genre to compare?
#     C. Which are the top 10 movies with maximum ROI? assuming ROI as (Box Office Collection -Budget)/Budget
#     D. Do Movies have higher ROI if they get released on festive seasons or long weekends? Hint: Check the average ROI for different release times.

# %%
bwd
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 0       1   2014-04-18                     2 States          LW   Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N    Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N    Comedy
# ..    ...          ...                          ...         ...       ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N    Comedy
# 145   146   2015-03-13                         NH10           N  Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148   2015-03-20                     Hunterrr           N    Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# ...

# %%
bwd[bwd["Budget"]>25].groupby("Month Name").count()
# Out:
#             SlNo  Release Date  MovieName  ReleaseTime  Genre  Budget  \
# Month Name
# April          4             4          4            4      4       4
# August         7             7          7            7      7       7
# December       2             2          2            2      2       2
# February       9             9          9            9      9       9
# January        6             6          6            6      6       6
# July           6             6          6            6      6       6
# June           5             5          5            5      5       5
# March          6             6          6            6      6       6
# May            3             3          3            3      3       3
# November       6             6          6            6      6       6
# October        4             4          4            4      4       4
# September      4             4          4            4      4       4
#
# ...

# %%
bwd[bwd["Budget"]>25].groupby("Month Name")["Release Date"].count()
# Out:
# Month Name
# April        4
# August       7
# December     2
# February     9
# January      6
# July         6
# June         5
# March        6
# May          3
# November     6
# October      4
# September    4
# Name: Release Date, dtype: int64

# %%
bwd[bwd["Budget"]>25].groupby("Month Name")["Release Date"].count().sort_values(ascending=False)
# Out:
# Month Name
# February     9
# August       7
# January      6
# July         6
# March        6
# November     6
# June         5
# April        4
# October      4
# September    4
# May          3
# December     2
# Name: Release Date, dtype: int64

# %%
bwd.groupby(bwd["Genre"])["YoutubeLikes"].sum()
# Out:
# Genre
# Action      401873
# Comedy      172250
# Drama       279077
# Romance     177241
# Thriller    143312
# Name: YoutubeLikes, dtype: int64

# %%
sns.boxplot(bwd['Genre'],bwd['YoutubeLikes'])
# Out:
# C:\Users\DIVYANSHU RAJ\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Genre', ylabel='YoutubeLikes'>

# %%
bwd['ROI']=(bwd['BoxOfficeCollection']-bwd['Budget'])/bwd['Budget']

# %%
bwd
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 0       1   2014-04-18                     2 States          LW   Romance
# 1       2   2013-01-04                 Table No. 21           N  Thriller
# 2       3   2014-07-18           Amit Sahni Ki List           N    Comedy
# 3       4   2013-01-04             Rajdhani Express           N     Drama
# 4       5   2014-07-04                 Bobby Jasoos           N    Comedy
# ..    ...          ...                          ...         ...       ...
# 144   145   2015-02-27           Dum Laga Ke Haisha           N    Comedy
# 145   146   2015-03-13                         NH10           N  Thriller
# 146   147   2015-03-20  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148   2015-03-20                     Hunterrr           N    Comedy
# 148   149   2014-05-23                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# ...

# %%
bwd.sort_values(by='ROI',ascending=False).head(10)
# Out:
#      SlNo Release Date                  MovieName ReleaseTime    Genre  \
# 64     65   2013-04-26                 Aashiqui 2           N  Romance
# 89     90   2014-12-19                         PK          HS    Drama
# 132   133   2013-09-13                Grand Masti          LW   Comedy
# 135   136   2013-09-20               The Lunchbox           N    Drama
# 87     88   2013-06-14                     Fukrey           N   Comedy
# 58     59   2014-09-05                   Mary Kom           N    Drama
# 128   129   2013-10-18                     Shahid          FS    Drama
# 37     38   2014-07-11  Humpty Sharma Ki Dulhania           N  Romance
# 101   102   2013-07-12         Bhaag Milkha Bhaag           N    Drama
# 115   116   2013-08-09            Chennai Express          FS   Comedy
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes  \
# 64       12                110.0       2926673          4944              628
# ...

# %%
bwd.groupby("ReleaseTime")['ROI'].mean()
# Out:
# ReleaseTime
# FS    0.973853
# HS    0.850867
# LW    1.127205
# N     0.657722
# Name: ROI, dtype: float64
